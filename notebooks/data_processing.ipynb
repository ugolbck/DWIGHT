# %%
import pandas as pd

# %%
PATH_DATA = '../src/data/the_office_lines_scripts.csv'

# %%
datafile = pd.read_csv(PATH_DATA)

# %%
datafile.head()
# Out:
#    id  season  episode  scene  \
# 0   1       1        1      1
# 1   2       1        1      1
# 2   3       1        1      1
# 3   4       1        1      1
# 4   5       1        1      1
#
#                                            line_text  speaker  deleted
# 0  All right Jim. Your quarterlies look very good...  Michael    False
# 1         Oh, I told you. I couldn't close it. So...      Jim    False
# 2  So you've come to the master for guidance? Is ...  Michael    False
# 3         Actually, you called me in here, but yeah.      Jim    False
# 4    All right. Well, let me show you how it's done.  Michael    False

# %%
datafile.loc[(datafile['speaker'] == 'Jim') & (datafile['season'] < 8)].reset_index(drop=True)
# Out:
#          id  season  episode  scene  \
# 0         2       1        1      1
# 1         4       1        1      1
# 2        18       1        1      6
# 3        20       1        1      7
# 4        26       1        1      7
# ...     ...     ...      ...    ...
# 5142  45664       7       24     69
# 5143  45682       7       24     71
# 5144  45692       7       24     71
# 5145  45694       7       24     71
# 5146  45696       7       24     71
#
#                                               line_text speaker  deleted
# 0            Oh, I told you. I couldn't close it. So...     Jim    False
# 1            Actually, you called me in here, but yeah.     Jim    False
# 2     My job is to speak to clients on the phone abo...     Jim    False
# 3         Whassup! I still love that after seven years.     Jim    False
# 4                                              Nothing.     Jim    False
# ...                                                 ...     ...      ...
# ...
